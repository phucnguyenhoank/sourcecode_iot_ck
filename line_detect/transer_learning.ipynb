# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Hàm tải và chuẩn bị dữ liệu từ thư mục ảnh
def load_data(data_dir):
    images = []
    labels = []
    for filename in os.listdir(data_dir):
        if filename.endswith(".jpg"):
            label = filename.split("_")[0]
            if label in ["right", "forward", "left"]:
                img = cv2.imread(os.path.join(data_dir, filename))
                img = cv2.resize(img, (224, 224))  # Resize về kích thước 224x224
                images.append(img)
                labels.append(["right", "forward", "left"].index(label))
    return np.array(images), np.array(labels)

# Tải dữ liệu và chia tập huấn luyện/validation
data_dir = "augmented_dataset"  # Thay bằng đường dẫn thực tế đến thư mục chứa ảnh
images, labels = load_data(data_dir)
train_images, val_images, train_labels, val_labels = train_test_split(images, labels, test_size=0.2, random_state=42)

# Chuẩn hóa dữ liệu (MobileNetV2 yêu cầu giá trị pixel trong [-1, 1])
train_images = tf.keras.applications.mobilenet_v2.preprocess_input(train_images)
val_images = tf.keras.applications.mobilenet_v2.preprocess_input(val_images)

# Định nghĩa mô hình với MobileNetV2
base_model = tf.keras.applications.MobileNetV2(input_shape=(224, 224, 3), include_top=False, weights="imagenet")
base_model.trainable = False  # Không huấn luyện lại MobileNetV2

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(3, activation="softmax")  # 3 lớp đầu ra: right, forward, left
])

# Compile mô hình
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Huấn luyện mô hình
history = model.fit(train_images, train_labels, epochs=15, validation_data=(val_images, val_labels))

# Vẽ đồ thị loss
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.savefig("loss_plot_clearn.png")  # Lưu đồ thị thành file
plt.close()

# Dự đoán trên tập validation
val_predictions = model.predict(val_images)
val_predictions = np.argmax(val_predictions, axis=1)  # Chuyển từ xác suất sang nhãn

# Tính confusion matrix
cm = confusion_matrix(val_labels, val_predictions)

# Vẽ confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
            xticklabels=["right", "forward", "left"], 
            yticklabels=["right", "forward", "left"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix on Validation Set")
plt.savefig("confusion_matrix_clean.png")  # Lưu confusion matrix thành file
plt.close()

# Lưu mô hình dưới dạng .tflite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open("steering_model_balanced.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# Epoch 1/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 633ms/step - accuracy: 0.4548 - loss: 1.1007 - val_accuracy: 0.7222 - val_loss: 0.6788
# Epoch 2/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 36s 605ms/step - accuracy: 0.7517 - loss: 0.6212 - val_accuracy: 0.7949 - val_loss: 0.5664
# Epoch 3/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 36s 617ms/step - accuracy: 0.8112 - loss: 0.5184 - val_accuracy: 0.8483 - val_loss: 0.4568
# Epoch 4/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 36s 607ms/step - accuracy: 0.8799 - loss: 0.4179 - val_accuracy: 0.8761 - val_loss: 0.3962
# Epoch 5/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 38s 641ms/step - accuracy: 0.9222 - loss: 0.3562 - val_accuracy: 0.8739 - val_loss: 0.3664
# Epoch 6/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 36s 606ms/step - accuracy: 0.9264 - loss: 0.3261 - val_accuracy: 0.9038 - val_loss: 0.3475
# Epoch 7/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 36s 604ms/step - accuracy: 0.9469 - loss: 0.2798 - val_accuracy: 0.9316 - val_loss: 0.2946
# Epoch 8/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 36s 605ms/step - accuracy: 0.9495 - loss: 0.2696 - val_accuracy: 0.9252 - val_loss: 0.2901
# Epoch 9/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 35s 602ms/step - accuracy: 0.9616 - loss: 0.2262 - val_accuracy: 0.9380 - val_loss: 0.2567
# Epoch 10/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 36s 614ms/step - accuracy: 0.9615 - loss: 0.2219 - val_accuracy: 0.9402 - val_loss: 0.2466
# Epoch 11/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 36s 604ms/step - accuracy: 0.9685 - loss: 0.2102 - val_accuracy: 0.9295 - val_loss: 0.2597
# Epoch 12/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 35s 602ms/step - accuracy: 0.9692 - loss: 0.1862 - val_accuracy: 0.9316 - val_loss: 0.2442
# Epoch 13/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 37s 623ms/step - accuracy: 0.9736 - loss: 0.1693 - val_accuracy: 0.9423 - val_loss: 0.2224
# Epoch 14/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 38s 641ms/step - accuracy: 0.9737 - loss: 0.1696 - val_accuracy: 0.9316 - val_loss: 0.2245
# Epoch 15/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 36s 615ms/step - accuracy: 0.9760 - loss: 0.1596 - val_accuracy: 0.9509 - val_loss: 0.2031
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 580ms/step
# INFO:tensorflow:Assets written to: C:\Users\nguye\AppData\Local\Temp\tmpomwoif4e\assets
# INFO:tensorflow:Assets written to: C:\Users\nguye\AppData\Local\Temp\tmpomwoif4e\assets
# Saved artifact at 'C:\Users\nguye\AppData\Local\Temp\tmpomwoif4e'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   2406553364512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587750128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587752240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587745552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587747840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587758400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587757344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587759984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587749248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587757872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406553366624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587912384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587915024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587910976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587912912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587756288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587918544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587921184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587917136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587919072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406587917488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588026720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588027776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588023552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588027072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588034112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588033056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588035696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588023200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588033584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588037104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588072000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588072176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588038160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588073760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588081152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588079392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588082208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588074112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588080448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588088016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588084496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588083792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588085200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588086784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588078336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588176464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588179104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588175056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588176992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588182976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588182096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588182448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588184032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588186320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588182800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588291152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588293792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588289744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588291680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588185088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588297312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588299952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588295904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588297840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588296256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588403024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588405840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588401616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588404080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588411648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588410592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588413232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588400736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588411120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588401968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588467328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588470144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588465568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588469088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588476480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588474720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588477536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588465744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588475776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588480176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681603840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681603488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588479472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681605600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2406588473664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681611584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681614224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681610176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681612112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681618096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681703552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681701792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681617392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681703904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681617920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681709888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681712528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681708480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681710416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681717104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681713584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681711120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681714288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681713232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681716224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681772608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681775424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681771200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681773664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681781232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681780176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681782816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681770320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681780704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681771552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681886240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681888880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681884832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681886768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681895216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681893456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681896272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681885184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681894512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681891168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682015904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682018544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682014496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682016432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408681892400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682023472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682026112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682022064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682024000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682028576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682097648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682097120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682098176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682098000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682028400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682103984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682106624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682102576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682104512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682109440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682177104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682176752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682108736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682178864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682186256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682184496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682187312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682179392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682185552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682189952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682189600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682189776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682191008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682243520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682183440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682247568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682250208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682246160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682248096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682256544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682254784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682257600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682246512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682255840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682252496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682377232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682379872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682375824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682377760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682253728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682384800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682387440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682383392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682385328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682383744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682475360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682476416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682472192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682475712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682482752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682481696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682484336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682471840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682482224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682487152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682554816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682553936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682557104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682556576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682565376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682563616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682566432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682553760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682564672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682569072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682636736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682635856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682639024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682638496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682562560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682643072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682645712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682641664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682643600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682648176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682647296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682647648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682649232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682718128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682648000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682723584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682726224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682722176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682724112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682650288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682731152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682727984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682729744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682731680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682730096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682836864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682839680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682835456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682837920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682845488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682844432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682847072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682834576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682844960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682835808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682950496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682953136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682949088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682951024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682959472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682957712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682960528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682949440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682958768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682955424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408683031184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408683033648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408683029072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408683032592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408682956656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408683037344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408683039984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408683035936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408683037872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408683410656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2408683408720: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Dự đoán trên tập validation
val_predictions = model.predict(val_images)
val_predictions = np.argmax(val_predictions, axis=1)  # Chuyển từ xác suất sang nhãn

# Tính confusion matrix
cm = confusion_matrix(val_labels, val_predictions)

# Vẽ confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
            xticklabels=["right", "forward", "left"], 
            yticklabels=["right", "forward", "left"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix on Validation Set")
plt.savefig("confusion_matrix_clean.png")  # Lưu confusion matrix thành file
plt.close()

# %%
# # Tải mô hình .tflite
# interpreter = tf.lite.Interpreter(model_path="steering_model_clean.tflite")
# interpreter.allocate_tensors()

# # Lấy thông tin input và output của mô hình
# input_details = interpreter.get_input_details()
# output_details = interpreter.get_output_details()

# # Kiểm tra trên luồng video
# stream_url = "http://192.168.46.130:81/stream"
# cap = cv2.VideoCapture(stream_url)

# while True:
#     ret, frame = cap.read()
#     if not ret:
#         print("Không thể đọc luồng video.")
#         break

#     # Chuẩn bị frame cho dự đoán
#     frame_resized = cv2.resize(frame, (224, 224))
#     frame_processed = tf.keras.applications.mobilenet_v2.preprocess_input(frame_resized)
#     input_data = np.expand_dims(frame_processed, axis=0).astype(np.float32)

#     # Đặt dữ liệu đầu vào và chạy dự đoán
#     interpreter.set_tensor(input_details[0]["index"], input_data)
#     interpreter.invoke()

#     # Lấy kết quả dự đoán
#     output_data = interpreter.get_tensor(output_details[0]["index"])
#     prediction = np.argmax(output_data[0])
#     result = ["right", "forward", "left"][prediction]
#     print(f"Dự đoán: {result}")

#     # Hiển thị frame (tùy chọn)
#     cv2.imshow("Video Stream", frame)
#     if cv2.waitKey(1) & 0xFF == ord("q"):  # Nhấn 'q' để thoát
#         break

# # Giải phóng tài nguyên
# cap.release()
# cv2.destroyAllWindows()
